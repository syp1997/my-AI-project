# %%
import torch
import pynvml
import time
 
pynvml.nvmlInit()#初始化
#设备情况
deviceCount = pynvml.nvmlDeviceGetCount()
print('GPU number：',deviceCount)
for i in range(deviceCount):
    handle = pynvml.nvmlDeviceGetHandleByIndex(i)
    gpu_name = pynvml.nvmlDeviceGetName(handle)
    print('GPU %d is :%s'%(i,gpu_name))
 
    #显存信息
    memo_info = pynvml.nvmlDeviceGetMemoryInfo(handle)
    print("GPU %d Memory Total: %.4f G"%(i,memo_info.total/1024/1024/1000) )
    print("GPU %d Memory Free: %.4f G"%(i,memo_info.free/1024/1024/1000))
    print("GPU %d Memory Used: %.4f G"%(i,memo_info.used/1024/1024/1000))
 
    #温度
    Temperature = pynvml.nvmlDeviceGetTemperature(handle, 0)
    print("Temperature is %.1f C" %(Temperature))
 
    #风扇转速
    speed = pynvml.nvmlDeviceGetFanSpeed(handle)
    print("Fan speed is ",speed)
 
    #电源状态
    power_ststus = pynvml.nvmlDeviceGetPowerState(handle)
    print("Power ststus", power_ststus)
    
for n in range(1000):
    time.sleep(10)
    memo_info = pynvml.nvmlDeviceGetMemoryInfo(handle)
    print("%d min: GPU Memory Used/Total: %.4f G/%.4f G"%(n/6, memo_info.used/1024/1024/1000,memo_info.total/1024/1024/1000) )

#关闭
pynvml.nvmlShutdown()
# Out:
# GPU number： 1
# GPU 0 is :b'GeForce RTX 2080 Ti'
# GPU 0 Memory Total: 11.0194 G
# GPU 0 Memory Free: 6.7322 G
# GPU 0 Memory Used: 4.2872 G
# Temperature is 25.0 C
# Fan speed is  30
# Power ststus 8
# 0 min: GPU Memory Used/Total: 4.2872 G/11.0194 G
# 0 min: GPU Memory Used/Total: 4.2872 G/11.0194 G
# 0 min: GPU Memory Used/Total: 4.2872 G/11.0194 G
# 0 min: GPU Memory Used/Total: 4.2872 G/11.0194 G
# 0 min: GPU Memory Used/Total: 0.0009 G/11.0194 G
# 0 min: GPU Memory Used/Total: 0.0122 G/11.0194 G
# 1 min: GPU Memory Used/Total: 0.0122 G/11.0194 G
# 1 min: GPU Memory Used/Total: 0.0122 G/11.0194 G
# 1 min: GPU Memory Used/Total: 0.0122 G/11.0194 G
# 1 min: GPU Memory Used/Total: 0.0122 G/11.0194 G
# 1 min: GPU Memory Used/Total: 0.0122 G/11.0194 G
# 1 min: GPU Memory Used/Total: 0.0122 G/11.0194 G
# 2 min: GPU Memory Used/Total: 0.4592 G/11.0194 G
# 2 min: GPU Memory Used/Total: 1.3732 G/11.0194 G
# 2 min: GPU Memory Used/Total: 1.3872 G/11.0194 G
# 2 min: GPU Memory Used/Total: 1.3872 G/11.0194 G
# 2 min: GPU Memory Used/Total: 1.3872 G/11.0194 G
# 2 min: GPU Memory Used/Total: 1.3872 G/11.0194 G
# 3 min: GPU Memory Used/Total: 1.3872 G/11.0194 G
# 3 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 3 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 3 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 3 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 3 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 4 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 4 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 4 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 4 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 4 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 4 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 5 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 5 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 5 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 5 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 5 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 5 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 6 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 6 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 6 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 6 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 6 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 6 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 7 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 7 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 7 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 7 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 7 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 7 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 8 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 8 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 8 min: GPU Memory Used/Total: 1.5092 G/11.0194 G
# 8 min: GPU Memory Used/Total: 1.5092 G/11.0194 G

# %%
def get_gpu_memory(handle):
    meminfo = pynvml.nvmlDeviceGetMemoryInfo(handle)
    free = meminfo.free/1024/1024/1000
    return free

pynvml.nvmlInit()
handle = pynvml.nvmlDeviceGetHandleByIndex(0)
print('Initial GPU memory：%.4f G'%get_gpu_memory(handle))
torch.cuda.empty_cache()
print('After torch.cuda.empty_cache, GPU memory：%.4f G' % get_gpu_memory(handle))
# del(model)
print('After del model, GPU memory：%.4f G'%get_gpu_memory(handle))
pynvml.nvmlShutdown()  # 最后关闭管理工具
